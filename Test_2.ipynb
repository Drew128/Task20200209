# %% [markdown]
# <a href="https://colab.research.google.com/github/Drew128/Task20200209/blob/master/Test_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-a26ffb23-ac25-4fcb-96f5-5fbf8de88530" name="files[]" multiple disabled />
#      <output id="result-a26ffb23-ac25-4fcb-96f5-5fbf8de88530">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving Test_2.csv to Test_2.csv

# %%
import pandas as pd
import numpy as np

df = pd.read_csv("Test_2.csv", delimiter=";", index_col=0, header=None).T
df['date'] = pd.to_datetime(df['date'])
for column_name in set(df.columns)-set(['date']):
  df[column_name] = pd.to_numeric(df[column_name],errors='coerce')

df
# Out:
# 0   RPU_0day  CPM_0day  Shows_by_user  ...  Click_to_reg       date  week_day
# 1      0.067      0.37          33.26  ...           7.8 2016-06-16         4
# 2      0.063      3.05          34.78  ...           7.1 2016-06-17         5
# 3      0.066      3.19          33.87  ...           8.6 2016-06-18         6
# 4      0.064      3.00          32.90  ...           8.9 2016-06-19         7
# 5      0.066      3.34          30.91  ...           8.5 2016-06-20         1
# 6      0.072      3.83          28.85  ...           9.4 2016-06-21         2
# 7      0.069      3.22          33.14  ...           9.7 2016-06-22         3
# 8      0.074      2.81          38.29  ...           9.2 2016-06-23         4
# 9      0.070      3.29          30.19  ...          10.5 2016-06-24         5
# 10     0.072      3.47          33.16  ...          10.7 2016-06-25         6
# 11     0.071      3.00          32.55  ...          11.6 2016-06-26         7
# ...

# %%
df.corr()
# Out:
# 0              RPU_0day  CPM_0day  ...  Click_to_reg  week_day
# 0                                  ...
# RPU_0day       1.000000  0.516894  ...     -0.071111  0.051791
# CPM_0day       0.516894  1.000000  ...      0.094097  0.069265
# Shows_by_user  0.259569 -0.089213  ...     -0.301193  0.289812
# ROI_0day       0.672337  0.392092  ...      0.592383  0.174498
# CostPer_reg   -0.131800 -0.046898  ...     -0.868776 -0.043519
# Regs           0.096776  0.035426  ...     -0.628395  0.016135
# Click_to_reg  -0.071111  0.094097  ...      1.000000 -0.062305
# week_day       0.051791  0.069265  ...     -0.062305  1.000000
#
# [8 rows x 8 columns]

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# with regression
sns.pairplot(df, kind="reg")

# %%
sns.lineplot(y=df['ROI_0day'], x=df['CostPer_reg'])

# %%
sns.lineplot(y=df['ROI_0day'], x=df['date'])
plt.legend(['ROI_0day'])

# %%
sns.lineplot(y=df['CostPer_reg'], x=df['date'])
plt.legend(['CostPer_reg'])
